# %%
import numpy as np
import pandas as pd

# %%
simbolo = [
    'IFNG',
    'Il10',
    'Tnf',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista

# %%
dicionario = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": gene_type,
    "chromosome": chromosome,

}
dicionario['simbolo']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2']

# %%
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array.shape
# Out:
# (6, 4)

# %%
gene_array[[3,2]]
#cahamar linhas inteiras expecificas em um array
# Out:
# array([['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434']],
#       dtype='<U27')

# %%
gene_array[:,[1,0]]
#chamar colunas expecifas no array
#somente : seleciona todas as linhas, e o segundo valor sera quais colunas que ele iria mostrar das linhas selecinadas, que no caso foi todas as linhas
# Out:
# array([['Il10', 'IFNG'],
#        ['interleukin 10', 'interferon gamma'],
#        ['RGD:2886', 'HGNC:HGNC:5438'],
#        ['protein coding', 'protein coding'],
#        ['Rattus norvegicus', 'Homo sapiens'],
#        ['13', '12']], dtype='<U27')
