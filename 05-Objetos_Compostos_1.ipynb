# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# Otimização de memoria, abstração de classes de objetos compostos, auto index,

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
passaros = ("curicaca", "tapicuro", "saracura", "bigua", "socozinho", )
passaros
# Out:
# ('curicaca', 'tapicuro', 'saracura', 'bigua', 'socozinho', 'curicaca')

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
passaros2 = ["sanhaço", "maracanã", "fragata", "curruira", "andorinha"]
passaros2
# Out:
# ['sanhaço', 'maracanã', 'fragata', 'curruira', 'andorinha']

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
gene_list = [
    "epsilon-adaptin",
    "PIK3CA",
    "GAPDH",
    "TcUGD",
    "TcGP72"
]
for i in gene_list:
    print(i.count("a")+i.count("A"))
# Out:
# 2
# 1
# 1
# 0
# 0

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
lista_ceratopsidae = [
    "triceratops",
    "estiracossauro",
    "torossauro",
    "pentaceratops",
    "pachyrhinosaurus"

]
lista_ceratopsidae [1:4]
# Out:
# ['estiracossauro', 'torossauro', 'pentaceratops']

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome = "Lucas"
nome[0],nome[-1]
# Out:
# ('L', 's')

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
dict_numbers = {
    "a" : 1,
    "b" : 2,
    "c" : 3,
    "d" : 4
}
print("a =",type(dict_numbers["a"]))
print("b =",type(dict_numbers["b"]))
print("c =",type(dict_numbers["c"]))
print("d =",type(dict_numbers["d"]))
print("numero de objetos no dicionario =",len(dict_numbers))
print("soma dos valores =",sum(dict_numbers.values()))
# Out:
# a = <class 'int'>
# b = <class 'int'>
# c = <class 'int'>
# d = <class 'int'>
# numero de objetos no dicionario = 4
# soma dos valores = 10

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
gene_list = [
    "epsilon-adaptin",
    "PIK3CA",
    "GAPDH",
    "TcUGD",
    "TcGP72"
]

gene_dict = {
    gene_list[0]:len(gene_list[0]),
    gene_list[1]:len(gene_list[1]),
    gene_list[2]:len(gene_list[2]),
    gene_list[3]:len(gene_list[3]),
    gene_list[4]:len(gene_list[4]),

}
gene_dict
# Out:
# {'epsilon-adaptin': 15, 'PIK3CA': 6, 'GAPDH': 5, 'TcUGD': 5, 'TcGP72': 6}

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
lista_gene_epsilon_adaptin = [
    len(gene_list[0]),
    (gene_list[0])[0:2],
    gene_list[0].count("a"),
    "hu" in gene_list[0],
]
print(lista_gene_epsilon_adaptin)

lista_gene_PIK3CA = [
    len(gene_list[1]),
    (gene_list[1])[0:2],
    gene_list[1].count("a"),
    "hu" in gene_list[1],
]
print(lista_gene_PIK3CA)

lista_gene_GAPDH = [
    len(gene_list[2]),
    (gene_list[2])[0:2],
    gene_list[2].count("a"),
    "hu" in gene_list[2],
]
print(lista_gene_GAPDH)

lista_TcUGD = [
    len(gene_list[3]),
    (gene_list[3])[0:2],
    gene_list[3].count("a"),
    "hu" in gene_list[3],
]
print(lista_TcUGD)

lista_gene_TcGP72 = [
    len(gene_list[4]),
    (gene_list[4])[0:2],
    gene_list[4].count("a"),
    "hu" in gene_list[4],
]
print(lista_gene_TcGP72)
# Out:
# [15, 'ep', 2, False]
# [6, 'PI', 0, False]
# [5, 'GA', 0, False]
# [5, 'Tc', 0, False]
# [6, 'Tc', 0, False]

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
gene_list_dict = {
    gene_list[0] : lista_gene_epsilon_adaptin,
    gene_list[1] : lista_gene_PIK3CA,
    gene_list[2] : lista_gene_GAPDH,
    gene_list[3] : lista_TcUGD,
    gene_list[4] : lista_gene_TcGP72



}
gene_list_dict
# Out:
# {'epsilon-adaptin': [15, 'ep', 2, False],
#  'PIK3CA': [6, 'PI', 0, False],
#  'GAPDH': [5, 'GA', 0, False],
#  'TcUGD': [5, 'Tc', 0, False],
#  'TcGP72': [6, 'Tc', 0, False]}
